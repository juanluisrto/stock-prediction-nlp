# %%
import yfinance as yf
import matplotlib.pyplot as plt

# %%
df = yf.download('GOOGL', 
                     period = "3Y",
                      #start='2019-01-01', 
                      #end='2019-12-31', 
                      progress=False)
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-03-06  846.859985  848.940002  841.169983  847.270020  847.270020
# 2017-03-07  847.260010  853.330017  845.520020  851.150024  851.150024
# 2017-03-08  853.119995  856.929993  851.250000  853.640015  853.640015
# 2017-03-09  853.690002  860.710022  852.669983  857.840027  857.840027
# 2017-03-10  862.700012  864.229980  857.609985  861.409973  861.409973
#
#              Volume
# Date
# 2017-03-06  1047900
# 2017-03-07  1038700
# 2017-03-08  1028800
# 2017-03-09  1347700
# 2017-03-10  1336600

# %%
fig, ax = plt.subplots(figsize=(15,5))

plt.plot(df.Close)

# %%
yf.Ticker.financials
# Out:
# yfinance.ticker.Ticker

# %% [markdown]
# https://www.quant-investing.com/blogs/general/2019/06/20/these-s-p-500-stocks-have-low-volatility
# https://markets.businessinsider.com/news/stocks/worst-performing-stocks-equities-2019-gap-kraft-heinz-biggest-declines-2019-12-1028786786#11-kohls1

# %%
5/7.
# Out:
# 0.7142857142857143

# %%
252./365
# Out:
# 0.6904109589041096

# %%
plt.plot(df.Close.rolling(252).std(ddof =0)*252**0.5)

# %%
df.Close.head(20)
# Out:
# Date
# 2017-03-06    252.009995
# 2017-03-07    250.899994
# 2017-03-08    250.240005
# 2017-03-09    250.179993
# 2017-03-10    248.380005
# 2017-03-13    248.160004
# 2017-03-14    247.720001
# 2017-03-15    246.779999
# 2017-03-16    248.220001
# 2017-03-17    243.940002
# 2017-03-20    242.139999
# 2017-03-21    233.000000
# 2017-03-22    231.070007
# 2017-03-23    231.899994
# 2017-03-24    228.410004
# 2017-03-27    225.479996
# 2017-03-28    229.330002
# 2017-03-29    228.449997
# 2017-03-30    231.220001
# 2017-03-31    229.720001
# Name: Close, dtype: float64

# %%
import tensorflow as tf
