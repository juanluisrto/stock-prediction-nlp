# %%
import os
import pandas as pd
import numpy as np

import seaborn as sns
from matplotlib import pyplot as plt


import pmdarima as pm
import statsmodels as st

from utils_time_series import *

# %%
ticker = "AAPL"
using_papermill = False

# %%
# Parameters
ticker = "PEP"
using_papermill = True

# %%
if not using_papermill:
    # %load_ext autoreload
    # %autoreload 2
    stocks = {}
    for file in os.listdir("stocks"):
        if ".parquet" in file:
            stock_name = file.rstrip(".parquet")
            df = pd.read_parquet(f"stocks/{file}")
            stocks[stock_name] = df
    print(stocks.keys())
    
    df = stocks[ticker]
else:
    df = pd.read_parquet(f"stocks/{ticker}.parquet")

# %%
df_raw = df.copy()

df["Close_diff"] = df.Close.diff(1)
df = (df.set_index("date")
        .asfreq("D")
        .ffill()
        .bfill()
     )
#we fill saturdays and sundays with friday values

# %%
fig, ax = plt.subplots(figsize = (20, 5))
sns.lineplot(data = df, x = "date", y = "Close", color="blue", label=ticker, linestyle="-")
sns.lineplot(data = df, x = "date", y = "High", color="red", linestyle="dashed")
sns.lineplot(data = df, x = "date", y = "Low",  color="red", linestyle="dashed")
# Out:
# <AxesSubplot:xlabel='date', ylabel='Close'>

# %% [markdown]
# ### Check for stationarity

# %%
stationary_test = pm.arima.ADFTest()
stationary_test.should_diff(df.Close)
# Out:
# (0.09107725455938309, True)

# %%
first_diff = df.Close.diff(periods = 1).dropna()
print(stationary_test.should_diff(first_diff))

fig, ax = plt.subplots(figsize = (20, 5))
sns.lineplot(data = first_diff, label=ticker, linestyle="-")
# Out:
# (0.01, False)
# <AxesSubplot:xlabel='date', ylabel='Close'>

# %% [markdown]
# ### Autocorrelation and partial-autocorrelation
# * acf is used to determine MA order
# * pacf is used to determine AR order
#
# https://towardsdatascience.com/interpreting-acf-and-pacf-plots-for-time-series-forecasting-af0d6db4061c#:~:text=The%20difference%20between%20ACF%20and,indicator%20of%20the%20significance%20threshold.

# %%
acf_p_values = pm.acf(first_diff)
pacf_p_values = pm.pacf(first_diff, method = "ols")

p_values_df = pd.DataFrame({"acf" : acf_p_values, "pacf" : pacf_p_values}).round(2)

# %%
(p_values_df[
    (p_values_df > 0.05).any(axis = 1)
].T
 .style
 .background_gradient(axis = None)
 .format(precision =2)
)
# Out:
# <style type="text/css">
# #T_e833a_row0_col0, #T_e833a_row1_col0 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_e833a_row0_col1, #T_e833a_row0_col3, #T_e833a_row0_col9 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_e833a_row0_col2, #T_e833a_row0_col5 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_e833a_row0_col4, #T_e833a_row0_col8, #T_e833a_row1_col4 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_e833a_row0_col6 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_e833a_row0_col7, #T_e833a_row1_col3 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_e833a_row0_col10, #T_e833a_row1_col8 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_e833a_row0_col11, #T_e833a_row1_col7, #T_e833a_row1_col10 {
#   background-color: #f5eef6;
#   color: #000000;
# }
# #T_e833a_row1_col1 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_e833a_row1_col2 {
#   background-color: #e2dfee;
#   color: #000000;
# }
# #T_e833a_row1_col5, #T_e833a_row1_col6 {
#   background-color: #ede8f3;
#   color: #000000;
# }
# #T_e833a_row1_col9 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_e833a_row1_col11 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_e833a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e833a_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_e833a_level0_col1" class="col_heading level0 col1" >2</th>
#       <th id="T_e833a_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_e833a_level0_col3" class="col_heading level0 col3" >7</th>
#       <th id="T_e833a_level0_col4" class="col_heading level0 col4" >9</th>
#       <th id="T_e833a_level0_col5" class="col_heading level0 col5" >11</th>
#       <th id="T_e833a_level0_col6" class="col_heading level0 col6" >13</th>
#       <th id="T_e833a_level0_col7" class="col_heading level0 col7" >16</th>
#       <th id="T_e833a_level0_col8" class="col_heading level0 col8" >20</th>
#       <th id="T_e833a_level0_col9" class="col_heading level0 col9" >22</th>
#       <th id="T_e833a_level0_col10" class="col_heading level0 col10" >23</th>
#       <th id="T_e833a_level0_col11" class="col_heading level0 col11" >24</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e833a_level0_row0" class="row_heading level0 row0" >acf</th>
#       <td id="T_e833a_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_e833a_row0_col1" class="data row0 col1" >0.07</td>
#       <td id="T_e833a_row0_col2" class="data row0 col2" >0.18</td>
#       <td id="T_e833a_row0_col3" class="data row0 col3" >0.07</td>
#       <td id="T_e833a_row0_col4" class="data row0 col4" >0.14</td>
#       <td id="T_e833a_row0_col5" class="data row0 col5" >0.18</td>
#       <td id="T_e833a_row0_col6" class="data row0 col6" >0.19</td>
#       <td id="T_e833a_row0_col7" class="data row0 col7" >0.03</td>
#       <td id="T_e833a_row0_col8" class="data row0 col8" >0.14</td>
#       <td id="T_e833a_row0_col9" class="data row0 col9" >0.07</td>
#       <td id="T_e833a_row0_col10" class="data row0 col10" >0.02</td>
#       <td id="T_e833a_row0_col11" class="data row0 col11" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_e833a_level0_row1" class="row_heading level0 row1" >pacf</th>
#       <td id="T_e833a_row1_col0" class="data row1 col0" >1.00</td>
#       <td id="T_e833a_row1_col1" class="data row1 col1" >0.01</td>
#       <td id="T_e833a_row1_col2" class="data row1 col2" >0.16</td>
#       <td id="T_e833a_row1_col3" class="data row1 col3" >0.03</td>
#       <td id="T_e833a_row1_col4" class="data row1 col4" >0.14</td>
#       <td id="T_e833a_row1_col5" class="data row1 col5" >0.11</td>
#       <td id="T_e833a_row1_col6" class="data row1 col6" >0.11</td>
#       <td id="T_e833a_row1_col7" class="data row1 col7" >0.06</td>
#       <td id="T_e833a_row1_col8" class="data row1 col8" >0.02</td>
#       <td id="T_e833a_row1_col9" class="data row1 col9" >0.05</td>
#       <td id="T_e833a_row1_col10" class="data row1 col10" >0.06</td>
#       <td id="T_e833a_row1_col11" class="data row1 col11" >-0.01</td>
#     </tr>
#   </tbody>
# </table>

# %%
#first_diff = df.Close.diff(7).dropna()
fig, axes = plt.subplots(2,1, figsize = (15,10))
print(st.graphics.tsaplots.plot_acf(first_diff, ax = axes[0]))
print(st.graphics.tsaplots.plot_pacf(first_diff, ax = axes[1]))
# Out:
# Figure(1080x720)
# Figure(1080x720)
# /Users/juanluis/opt/anaconda3/envs/tfm/lib/python3.8/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
errors = {}
threshold = '2020-09-30 23:59:00'

train_df, test_df = train_test_split(df, threshold, )#train_pctg = 0.85)

# %%
forecaster = fit_arima_model(train_df, exog_cols = None)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2586.833, Time=0.19 sec
# First viable model found (2586.833)
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=2629.727, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2585.552, Time=0.03 sec
# New best model found (2585.552 < 2586.833)
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2588.639, Time=0.03 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=2628.102, Time=0.01 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=2587.504, Time=0.04 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=2587.443, Time=0.06 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=2586.558, Time=0.20 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=2584.184, Time=0.02 sec
# New best model found (2584.184 < 2585.552)
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=2586.124, Time=0.02 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=2586.046, Time=0.03 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=2587.332, Time=0.02 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=2585.142, Time=0.08 sec
#
# Best model:  ARIMA(1,1,0)(0,0,0)[0]
# Total fit time: 0.740 seconds

# %%
forecaster.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  639
# Model:               SARIMAX(1, 1, 0)   Log Likelihood               -1290.092
# Date:                Thu, 27 Apr 2023   AIC                           2584.184
# Time:                        19:26:30   BIC                           2593.101
# Sample:                    01-01-2019   HQIC                          2587.646
#                          - 09-30-2020
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.2634      0.014    -19.077      0.000      -0.290      -0.236
# sigma2         3.3407      0.052     64.292      0.000       3.239       3.443
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):             15893.21
# Prob(Q):                              0.98   Prob(JB):                         0.00
# Heteroskedasticity (H):               9.88   Skew:                            -1.78
# Prob(H) (two-sided):                  0.00   Kurtosis:                        27.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
pred_df = predict_arima_ahead_update(forecaster, test_df, exog_cols = None)
errors["rsme_arima_close"] = compute_test_error(pred_df)
# Out:
# Test error (rmse): 1.203741662866961

# %% [markdown]
# The arima model is clearly predicting the value of the previous day.
#
# Lets see if we can add some exogenous variables from the news data

# %%
gb_forecaster = fit_model(train_df, target_col="Close_diff", exog_cols = None)
pred_df = predict_ahead(gb_forecaster, test_df, exog_cols = None)
pred_df["pred_sum"] = pred_df["pred"].cumsum() + pred_df.iloc[0].Close
errors["rsme_gb_close_diff"] = compute_test_error(pred_df, y_pred_col = "pred",     y_true_col = "Close_diff")
errors["rsme_gb_close"] = compute_test_error(pred_df, y_pred_col = "pred_sum", y_true_col = "Close")
# Out:
# Test error (rmse): 1.2483035139667888
# Test error (rmse): 13.662317373879121

# %% [markdown]
# ## Exogenous variables

# %%
def best_sentiment_score_lags(df, ticker, num_lags = 30, corr_threshold = 0.1):
    df = df.copy()
    for i in range(0,num_lags):
        df[f"tails_score_lag_{i}"] = df.tails_median_score.shift(i)
    tails_lag_corr = df.corr()[["Close"]].iloc[3:]
    
    fig, ax = plt.subplots(figsize = (10,5))

    tails_lag_corr.plot(ax = ax, title = f"Cross correlation with lagged tails sentiment score: {ticker}")
    plt.xticks(rotation=45)
    plt.show()
    return tails_lag_corr[(tails_lag_corr.abs() > corr_threshold).values]

# %%
tails_df = train_df[["Close", "tails_median_score"]].copy()
tails_df.Close = tails_df.Close.diff(1) #we differenciate

# We compute the correlation of the change in the close value with the sentiment score at different lags.
# This way we detect how news correlate with change and how many days does it take to make this change
tails_lag_corr = best_sentiment_score_lags(tails_df, ticker, corr_threshold= 0.06)

# %%
tails_lag_corr
# Out:
#                        Close
# tails_score_lag_12 -0.070028
# tails_score_lag_16 -0.063682
# tails_score_lag_26  0.094415

# %%
for feature in tails_lag_corr.index:
    lag_value = int(feature.split("_")[-1])
    df[feature] = df.tails_median_score.shift(lag_value)

# %%
exog_cols = tails_lag_corr.index.values.tolist() + ["tails_median_score"]

train_df, test_df = train_test_split(df, threshold, )#train_pctg = 0.85)
train_df = train_df.dropna(subset = exog_cols) # we drop the first rows in training where we dont have data.

# %%
model = pm.arima.ARIMA(order = forecaster.order, suppress_warnings = True)
forecaster = model.fit(train_df.Close, X = train_df[exog_cols])
#forecaster = fit_arima_model(train_df, exog_cols = exog_cols)
pred_df = predict_arima_ahead_update(forecaster, test_df, exog_cols = exog_cols)
errors["rsme_arima_close_exog"] = compute_test_error(pred_df, y_true_col="Close", exog_cols = exog_cols)
# Out:
# Test error (rmse): 1.2467153751009084
# Exog cols : ['tails_score_lag_12', 'tails_score_lag_16', 'tails_score_lag_26', 'tails_median_score']

# %%
gb_forecaster = fit_model(train_df, target_col="Close_diff", exog_cols = exog_cols)
pred_df = predict_ahead(gb_forecaster, test_df, exog_cols = exog_cols)
pred_df["pred_sum"] = pred_df["pred"].cumsum() + pred_df.iloc[0].Close
errors["rsme_gb_close_diff_exog"] = compute_test_error(pred_df, y_pred_col = "pred",     y_true_col = "Close_diff")
errors["rsme_gb_close_exog"] = compute_test_error(pred_df, y_pred_col = "pred_sum", y_true_col = "Close")
# Out:
# Test error (rmse): 1.1517585577771587
# Test error (rmse): 9.161685461457726

# %%
errors
# Out:
# {'rsme_arima_close': 1.203741662866961,
#  'rsme_gb_close_diff': 1.2483035139667888,
#  'rsme_gb_close': 13.662317373879121,
#  'rsme_arima_close_exog': 1.2467153751009084,
#  'rsme_gb_close_diff_exog': 1.1517585577771587,
#  'rsme_gb_close_exog': 9.161685461457726}

# %%
print("Is exog better?",errors["rsme_arima_close"] > errors["rsme_arima_close_exog"])
# Out:
# Is exog better? False

# %% [markdown]
# # Borrador

# %%
raw = df_raw[["Close", "tails_median_score"]].copy()

# %%
raw["Close_diff"] = raw.Close.diff(1)

# %%
q1, q3 = df.Close_diff.quantile([0.25, 0.75]).values

def growth(x):
    if x >= q3:
        return 1
    elif x <= q1:
        return -1
    else:
        return 0

# %%
raw["stock_growth"] = raw.Close_diff.apply(growth)

# %%
from sklearn.cluster import KMeans

# %%
scores = raw.tails_median_score
CLUSTERS = 3
if scores.isna().any():
    CLUSTERS+=1
    nan_value = scores.max() + (scores.max() - scores.min())*100
    scores =scores.fillna(nan_value)
data = scores.values.reshape(-1,1)
preds = KMeans(CLUSTERS).fit_predict(data)

# %%
kmeans_df = pd.DataFrame({"score" : scores, "cluster" : preds})

# %%
kmeans_df = kmeans_df.where(kmeans_df.score != nan_value, None)

# %%
cluster_indices = kmeans_df.groupby("cluster").mean().sort_values("score").index.values
cluster_mapping = { assigned_cluster: real_cluster for real_cluster, assigned_cluster in zip(range(CLUSTERS),cluster_indices)}

# %%
raw["sentiment_growth"] = kmeans_df.cluster.apply(cluster_mapping.get) - 1

# %%
from sklearn.metrics import confusion_matrix

# %%
growth_df = (raw[["sentiment_growth", "stock_growth"]]
             .dropna()
             .astype(int))

# %%
growth_df.sentiment_growth.value_counts()
# Out:
# -1    273
#  1    264
#  0    149
# Name: sentiment_growth, dtype: int64

# %%
(growth_df.sentiment_growth == growth_df.stock_growth).sum() / len (growth_df)
# Out:
# 0.27405247813411077

# %%
from sklearn.metrics import accuracy_score

# %%
#growth_df[growth_df.stock_growth != 0]
